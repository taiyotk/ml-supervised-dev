# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("../data/Customer Call List.xlsx")
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %% [markdown]
# #### Removendo valores duplicados

# %%
df[df.duplicated()]
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 20        1020     Anakin  Skywalker  876|678|3469
#
#                         Address Paying Customer Do_Not_Contact  \
# 20  910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 20               True

# %%
df = df.drop_duplicates()
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 19        1020     Anakin  Skywalker  876|678|3469
# 20        1020     Anakin  Skywalker  876|678|3469
#
#                         Address Paying Customer Do_Not_Contact  \
# 19  910 Tatooine Road, Tatooine             Yes              N
# 20  910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 19               True
# 20               True

# %% [markdown]
# #### Removendo coluna desnecesária

# %%
df = df.drop(columns = "Not_Useful_Column")
df

# %% [markdown]
# #### Remove espaços em branco e outros caracteres

# %%
df["Last_Name"] = df["Last_Name"].str.strip("123._/") # Argumento opcional
df

# %% [markdown]
# #### Padronizando valores categóricos

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('Yes','Y')

df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('No','N')
df

# %% [markdown]
# #### Lidando com valores faltantes

# %%
"""
É necessário avaliar se apenas remover é o suficiente.
Se o volume de nulos for muito alto, essa não é uma boa opção.
"""

df=df.fillna('')
df

# %% [markdown]
# #### Atualizando índices

# %%
df = df.reset_index(drop=True)
df

# %% [markdown]
# #### N-Gramas

# %% [markdown]
# #### TF-IDF
